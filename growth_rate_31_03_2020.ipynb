# %%
import os
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy.stats import chisquare
from functools import reduce

# %%
os.getcwd()
# Out:
# 'C:\\Users\\icon'

# %%
os.chdir("E:\\Sustainable agriculture\\Veg data\\veg analysis")

# %%
potato_area=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\area_new\\potato_area.xlsx")
tomato_area=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\area_new\\tomato_area.xlsx")
onion_area=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\area_new\\onion_area.xlsx")
leafyveg_area=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\area_new\\leafyveg_area.xlsx")
khol_area=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\area_new\\khol_area.xlsx")
gaurd_area=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\area_new\\gaurd_area.xlsx")
otherveg_area=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\area_new\\otherveg_area.xlsx")
total_area=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\area_new\\total_area.xlsx")

# %%
potato_prod=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\production_new\\potato_prod.xlsx")
tomato_prod=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\production_new\\tomato_prod.xlsx")
onion_prod=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\production_new\\onion_prod.xlsx")
leafyveg_prod=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\production_new\\leafyveg_prod.xlsx")
khol_prod=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\production_new\\khol_prod.xlsx")
gaurd_prod=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\production_new\\gaurd_prod.xlsx")
otherveg_prod=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\production_new\\otherveg_prod.xlsx")
total_prod=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\production_new\\total_prod.xlsx")

# %%
potato_prod.reset_index(drop=True, inplace=True)
tomato_prod.reset_index(drop=True, inplace=True)
onion_prod.reset_index(drop=True, inplace=True)
leafyveg_prod.reset_index(drop=True, inplace=True)
khol_prod.reset_index(drop=True, inplace=True)
gaurd_prod.reset_index(drop=True, inplace=True)
otherveg_prod.reset_index(drop=True, inplace=True)
total_prod.reset_index(drop=True, inplace=True)

# %%
potato_area.reset_index(drop=True, inplace=True)
tomato_area.reset_index(drop=True, inplace=True)
onion_area.reset_index(drop=True, inplace=True)
leafyveg_area.reset_index(drop=True, inplace=True)
khol_area.reset_index(drop=True, inplace=True)
gaurd_area.reset_index(drop=True, inplace=True)
otherveg_area.reset_index(drop=True, inplace=True)
total_area.reset_index(drop=True, inplace=True)

# %%
potato_prod.drop(['years'],axis=1,inplace=True)
potato_area.drop(['years'],axis=1,inplace=True)
tomato_area.drop(['years'],axis=1,inplace=True)
tomato_prod.drop(['years'],axis=1,inplace=True)
onion_area.drop(['years'],axis=1,inplace=True)
onion_prod.drop(['years'],axis=1,inplace=True)
gaurd_area.drop(['years'],axis=1,inplace=True)
gaurd_prod.drop(['years'],axis=1,inplace=True)
khol_area.drop(['years'],axis=1,inplace=True)
khol_prod.drop(['years'],axis=1,inplace=True)
leafyveg_area.drop(['years'],axis=1,inplace=True)
leafyveg_prod.drop(['years'],axis=1,inplace=True)
otherveg_area.drop(['years'],axis=1,inplace=True)
otherveg_prod.drop(['years'],axis=1,inplace=True)
total_area.drop(['years'],axis=1,inplace=True)
total_prod.drop(['years'],axis=1,inplace=True)

# %%
potato_yield=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\yield\\potato_yield.xlsx")
tomato_yield=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\yield\\tomato_yield.xlsx")
onion_yield=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\yield\\onion_yield.xlsx")
gaurd_yield=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\yield\\gaurd_yield.xlsx")
khol_yield=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\yield\\khol_yield.xlsx")
leafyveg_yield=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\yield\\leafyveg_yield.xlsx")
otherveg_yield=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\yield\\otherveg_yield.xlsx")
total_yield=pd.read_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\yield\\total_yield.xlsx")

# %%
plt.plot(potato_area['State Total'])
plt.plot(tomato_area['State Total'])
plt.plot(onion_area['State Total'])
plt.plot(leafyveg_area['State Total'])
plt.plot(khol_area['State Total'])
plt.plot(gaurd_area['State Total'])
plt.plot(total_area['State Total'])

# %%
y = np.log(potato_area['Kolar_new'])
x = sm.add_constant(potato_area.index)
result = sm.OLS(y,x).fit()
result.summary()
result.params[1]
# Out:
# F:\Python\lib\site-packages\scipy\stats\stats.py:1394: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   "anyway, n=%i" % int(n))
# 0.0031896349636972854

# %%
y = np.log(tomato_area['Kolar_new'])
x = sm.add_constant(tomato_area.index)
result = sm.OLS(y,x).fit()
result.summary()
result.params[1]
# Out:
# F:\Python\lib\site-packages\scipy\stats\stats.py:1394: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=19
#   "anyway, n=%i" % int(n))
# 0.021075477588020516

# %%
col_list1 = list(potato_area)
col_list2 = list(tomato_area)
col_list3 = list(onion_area)
col_list4 = list(gaurd_area)
col_list5 = list(khol_area)
col_list6 = list(leafyveg_area)
col_list7 = list(otherveg_area)
col_list8 = list(total_area)
col_list9 = list(potato_prod)
col_list10 = list(tomato_prod)
col_list11 = list(onion_prod)
col_list12 = list(gaurd_prod)
col_list13 = list(khol_prod)
col_list14 = list(leafyveg_prod)
col_list15 = list(otherveg_prod)
col_list16 = list(total_prod)
col_list17 = list(potato_yield)
col_list18 = list(tomato_yield)
col_list19 = list(onion_yield)
col_list20 = list(gaurd_yield)
col_list21 = list(khol_yield)
col_list22 = list(leafyveg_yield)
col_list23 = list(otherveg_yield)
col_list24 = list(total_yield)

# %%
col_list24
# Out:
# ['Chitradurga',
#  'Davangere',
#  'Bagalkot',
#  'Balgaum',
#  'Dharwad',
#  'Gadag',
#  'Haveri',
#  'Koppal',
#  'Chamrajanagar',
#  'Chikkamagalur',
#  'Hassan',
#  'Mandya',
#  'State Total',
#  'Bangalore®_new',
#  'Kolar_new']

# %%
output1 = pd.DataFrame()
for i,j in zip(np.arange(0,potato_area.shape[1]+1),col_list1):
    x = sm.add_constant(potato_area.index)
    result = sm.OLS(np.log(potato_area.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','potato_area'])
    output1 = pd.concat([output1, data], axis=0)
output1
# Out:
# F:\Python\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
#         Districts  potato_area
# 0     Chitradurga          NaN
# 0       Davangere          NaN
# 0        Bagalkot          NaN
# 0         Balgaum       -0.030
# 0         Dharwad       -0.047
# 0           Gadag          NaN
# 0          Haveri          NaN
# 0          Koppal          NaN
# 0   Chamrajanagar        0.307
# 0   Chikkamagalur        0.053
# 0          Hassan       -0.039
# 0          Mandya        0.055
# 0     State Total       -0.025
# 0  Bangalore®_new       -0.041
# 0       Kolar_new        0.003

# %%
output2 = pd.DataFrame()
for i,j in zip(np.arange(0,tomato_area.shape[1]+1),col_list2):
    x = sm.add_constant(tomato_area.index)
    result = sm.OLS(np.log(tomato_area.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','tomato_area'])
    output2 = pd.concat([output2, data], axis=0)
output2
# Out:
#         Districts  tomato_area
# 0     Chitradurga        0.073
# 0       Davangere        0.095
# 0        Bagalkot       -0.002
# 0         Balgaum        0.047
# 0         Dharwad        0.019
# 0           Gadag       -0.014
# 0          Haveri        0.052
# 0          Koppal        0.093
# 0   Chamrajanagar        0.147
# 0   Chikkamagalur        0.046
# 0          Hassan       -0.010
# 0          Mandya        0.043
# 0     State Total        0.034
# 0  Bangalore®_new       -0.029
# 0       Kolar_new        0.021

# %%
output3 = pd.DataFrame()
for i,j in zip(np.arange(0,onion_area.shape[1]+1),col_list2):
    x = sm.add_constant(onion_area.index)
    result = sm.OLS(np.log(onion_area.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','onion_area'])
    output3 = pd.concat([output3, data], axis=0)
output3
# Out:
#         Districts  onion_area
# 0     Chitradurga       0.030
# 0       Davangere       0.008
# 0        Bagalkot       0.100
# 0         Balgaum       0.038
# 0         Dharwad      -0.030
# 0           Gadag       0.060
# 0          Haveri       0.023
# 0          Koppal       0.203
# 0   Chamrajanagar       0.104
# 0   Chikkamagalur       0.053
# 0          Hassan      -0.084
# 0          Mandya       0.021
# 0     State Total       0.036
# 0  Bangalore®_new      -0.038
# 0       Kolar_new      -0.001

# %%
output4 = pd.DataFrame()
for i,j in zip(np.arange(0,gaurd_area.shape[1]+1),col_list4):
    x = sm.add_constant(gaurd_area.index)
    result = sm.OLS(np.log(gaurd_area.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','gaurd_area'])
    output4 = pd.concat([output4, data], axis=0)
output4
# Out:
# F:\Python\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
#         Districts  gaurd_area
# 0     Chitradurga    0.041000
# 0       Davangere    0.054000
# 0        Bagalkot   -0.031000
# 0         Balgaum    0.021000
# 0         Dharwad    0.107000
# 0           Gadag    0.026000
# 0          Haveri         inf
# 0          Koppal    0.086000
# 0   Chamrajanagar    0.106000
# 0   Chikkamagalur    0.075000
# 0          Hassan    0.093000
# 0          Mandya         inf
# 0     State Total    0.028000
# 0  Bangalore®_new    0.006000
# 0       Kolar_new    0.010000

# %%
output5 = pd.DataFrame()
for i,j in zip(np.arange(0,khol_area.shape[1]+1),col_list5):
    x = sm.add_constant(khol_area.index)
    result = sm.OLS(np.log(khol_area.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','khol_area'])
    output5 = pd.concat([output5, data], axis=0)
output5
# Out:
# F:\Python\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
#         Districts  khol_area
# 0     Chitradurga     -0.058
# 0       Davangere      0.116
# 0        Bagalkot      0.006
# 0         Balgaum      0.057
# 0         Dharwad      0.052
# 0           Gadag      0.126
# 0          Haveri      0.069
# 0          Koppal        NaN
# 0   Chamrajanagar      0.162
# 0   Chikkamagalur      0.029
# 0          Hassan     -0.019
# 0          Mandya      0.030
# 0     State Total      0.036
# 0  Bangalore®_new     -0.020
# 0       Kolar_new      0.054

# %%
output6 = pd.DataFrame()
for i,j in zip(np.arange(0,leafyveg_area.shape[1]+1),col_list6):
    x = sm.add_constant(leafyveg_area.index)
    result = sm.OLS(np.log(leafyveg_area.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','leafyveg_area'])
    output6 = pd.concat([output6, data], axis=0)
output6
# Out:
# F:\Python\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
#         Districts  leafyveg_area
# 0     Chitradurga      -0.015000
# 0       Davangere      -0.011000
# 0        Bagalkot      -0.029000
# 0         Balgaum       0.005000
# 0         Dharwad            NaN
# 0           Gadag      -0.026000
# 0          Haveri       0.091000
# 0          Koppal           -inf
# 0   Chamrajanagar       0.101000
# 0   Chikkamagalur      -0.032000
# 0          Hassan       0.067000
# 0          Mandya            inf
# 0     State Total      -0.001000
# 0  Bangalore®_new      -0.026000
# 0       Kolar_new       0.065000

# %%
output7 = pd.DataFrame()
for i,j in zip(np.arange(0,otherveg_area.shape[1]+1),col_list7):
    x = sm.add_constant(otherveg_area.index)
    result = sm.OLS(np.log(otherveg_area.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','otherveg_area'])
    output7 = pd.concat([output7, data], axis=0)
output7
# Out:
#         Districts  otherveg_area
# 0     Chitradurga         -0.134
# 0       Davangere         -0.114
# 0        Bagalkot         -0.141
# 0         Balgaum         -0.059
# 0         Dharwad         -0.208
# 0           Gadag         -0.131
# 0          Haveri         -0.169
# 0          Koppal         -0.183
# 0   Chamrajanagar         -0.030
# 0   Chikkamagalur         -0.031
# 0          Hassan         -0.097
# 0          Mandya         -0.086
# 0     State Total         -0.080
# 0  Bangalore®_new         -0.071
# 0       Kolar_new         -0.011

# %%
output8 = pd.DataFrame()
for i,j in zip(np.arange(0,total_area.shape[1]+1),col_list8):
    x = sm.add_constant(total_area.index)
    result = sm.OLS(np.log(total_area.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','total_area'])
    output8 = pd.concat([output8, data], axis=0)
output8
# Out:
#         Districts  total_area
# 0     Chitradurga       0.028
# 0       Davangere       0.034
# 0        Bagalkot       0.061
# 0         Balgaum       0.014
# 0         Dharwad      -0.026
# 0           Gadag       0.045
# 0          Haveri       0.038
# 0          Koppal       0.119
# 0   Chamrajanagar       0.110
# 0   Chikkamagalur       0.040
# 0          Hassan      -0.038
# 0          Mandya       0.022
# 0     State Total       0.018
# 0  Bangalore®_new      -0.031
# 0       Kolar_new       0.018

# %%
output9 = pd.DataFrame()
for i,j in zip(np.arange(0,potato_prod.shape[1]+1),col_list9):
    x = sm.add_constant(potato_prod.index)
    result = sm.OLS(np.log(potato_prod.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','potato_prod'])
    output9 = pd.concat([output9, data], axis=0)
output9
# Out:
# F:\Python\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
#         Districts  potato_prod
# 0     Chitradurga          NaN
# 0       Davangere          NaN
# 0        Bagalkot          NaN
# 0         Balgaum       -0.002
# 0         Dharwad        0.088
# 0           Gadag          NaN
# 0          Haveri          NaN
# 0          Koppal          NaN
# 0   Chamrajanagar        0.349
# 0   Chikkamagalur        0.114
# 0          Hassan       -0.018
# 0          Mandya        0.085
# 0     State Total       -0.005
# 0  Bangalore®_new       -0.044
# 0       Kolar_new        0.012

# %%
output10 = pd.DataFrame()
for i,j in zip(np.arange(0,tomato_prod.shape[1]+1),col_list10):
    x = sm.add_constant(tomato_prod.index)
    result = sm.OLS(np.log(tomato_prod.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','tomato_prod'])
    output10 = pd.concat([output10, data], axis=0)
output10
# Out:
#         Districts  tomato_prod
# 0     Chitradurga        0.073
# 0       Davangere        0.112
# 0        Bagalkot        0.001
# 0         Balgaum        0.046
# 0         Dharwad        0.034
# 0           Gadag        0.021
# 0          Haveri        0.084
# 0          Koppal        0.107
# 0   Chamrajanagar        0.150
# 0   Chikkamagalur        0.063
# 0          Hassan        0.023
# 0          Mandya        0.110
# 0     State Total        0.053
# 0  Bangalore®_new       -0.024
# 0       Kolar_new        0.058

# %%
output11 = pd.DataFrame()
for i,j in zip(np.arange(0,onion_prod.shape[1]+1),col_list11):
    x = sm.add_constant(onion_prod.index)
    result = sm.OLS(np.log(onion_prod.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','onion_prod'])
    output11 = pd.concat([output11, data], axis=0)
output11
# Out:
#         Districts  onion_prod
# 0     Chitradurga       0.057
# 0       Davangere       0.062
# 0        Bagalkot       0.120
# 0         Balgaum       0.115
# 0         Dharwad       0.041
# 0           Gadag       0.056
# 0          Haveri       0.071
# 0          Koppal       0.239
# 0   Chamrajanagar       0.101
# 0   Chikkamagalur       0.092
# 0          Hassan      -0.042
# 0          Mandya       0.041
# 0     State Total       0.075
# 0  Bangalore®_new      -0.004
# 0       Kolar_new       0.036

# %%
output12 = pd.DataFrame()
for i,j in zip(np.arange(0,gaurd_prod.shape[1]+1),col_list12):
    x = sm.add_constant(gaurd_prod.index)
    result = sm.OLS(np.log(gaurd_prod.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','gaurd_prod'])
    output12 = pd.concat([output12, data], axis=0)
output12
# Out:
# F:\Python\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
#         Districts  gaurd_prod
# 0     Chitradurga    0.043000
# 0       Davangere    0.051000
# 0        Bagalkot   -0.000000
# 0         Balgaum    0.021000
# 0         Dharwad    0.165000
# 0           Gadag    0.030000
# 0          Haveri         inf
# 0          Koppal    0.098000
# 0   Chamrajanagar    0.126000
# 0   Chikkamagalur    0.104000
# 0          Hassan    0.145000
# 0          Mandya         inf
# 0     State Total    0.038000
# 0  Bangalore®_new    0.002000
# 0       Kolar_new    0.029000

# %%
output13 = pd.DataFrame()
for i,j in zip(np.arange(0,khol_prod.shape[1]+1),col_list13):
    x = sm.add_constant(khol_prod.index)
    result = sm.OLS(np.log(khol_prod.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','khol_prod'])
    output13 = pd.concat([output13, data], axis=0)
output13
# Out:
# F:\Python\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
#         Districts  khol_prod
# 0     Chitradurga     -0.072
# 0       Davangere      0.133
# 0        Bagalkot      0.030
# 0         Balgaum      0.078
# 0         Dharwad      0.077
# 0           Gadag      0.137
# 0          Haveri      0.081
# 0          Koppal        NaN
# 0   Chamrajanagar      0.142
# 0   Chikkamagalur      0.047
# 0          Hassan     -0.015
# 0          Mandya      0.041
# 0     State Total      0.039
# 0  Bangalore®_new     -0.021
# 0       Kolar_new      0.050

# %%
output14 = pd.DataFrame()
for i,j in zip(np.arange(0,leafyveg_prod.shape[1]+1),col_list14):
    x = sm.add_constant(leafyveg_prod.index)
    result = sm.OLS(np.log(leafyveg_prod.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','leafyveg_prod'])
    output14 = pd.concat([output14, data], axis=0)
output14
# Out:
# F:\Python\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
#         Districts  leafyveg_prod
# 0     Chitradurga      -0.000000
# 0       Davangere       0.023000
# 0        Bagalkot      -0.014000
# 0         Balgaum       0.010000
# 0         Dharwad            NaN
# 0           Gadag      -0.037000
# 0          Haveri       0.077000
# 0          Koppal           -inf
# 0   Chamrajanagar       0.135000
# 0   Chikkamagalur      -0.014000
# 0          Hassan       0.108000
# 0          Mandya            inf
# 0     State Total       0.010000
# 0  Bangalore®_new      -0.027000
# 0       Kolar_new       0.081000

# %%
output15 = pd.DataFrame()
for i,j in zip(np.arange(0,otherveg_prod.shape[1]+1),col_list15):
    x = sm.add_constant(otherveg_prod.index)
    result = sm.OLS(np.log(otherveg_prod.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','otherveg_prod'])
    output15 = pd.concat([output15, data], axis=0)
output15
# Out:
#         Districts  otherveg_prod
# 0     Chitradurga         -0.165
# 0       Davangere         -0.109
# 0        Bagalkot         -0.154
# 0         Balgaum         -0.070
# 0         Dharwad         -0.206
# 0           Gadag         -0.124
# 0          Haveri         -0.173
# 0          Koppal         -0.216
# 0   Chamrajanagar         -0.084
# 0   Chikkamagalur         -0.059
# 0          Hassan         -0.101
# 0          Mandya         -0.115
# 0     State Total         -0.090
# 0  Bangalore®_new         -0.077
# 0       Kolar_new         -0.032

# %%
output16 = pd.DataFrame()
for i,j in zip(np.arange(0,total_prod.shape[1]+1),col_list16):
    x = sm.add_constant(total_prod.index)
    result = sm.OLS(np.log(total_prod.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','total_prod'])
    output16 = pd.concat([output16, data], axis=0)
output16
# Out:
#         Districts  total_prod
# 0     Chitradurga       0.051
# 0       Davangere       0.065
# 0        Bagalkot       0.079
# 0         Balgaum       0.037
# 0         Dharwad       0.027
# 0           Gadag       0.041
# 0          Haveri       0.065
# 0          Koppal       0.135
# 0   Chamrajanagar       0.119
# 0   Chikkamagalur       0.069
# 0          Hassan      -0.017
# 0          Mandya       0.056
# 0     State Total       0.039
# 0  Bangalore®_new      -0.032
# 0       Kolar_new       0.039

# %%
output17 = pd.DataFrame()
for i,j in zip(np.arange(0,potato_yield.shape[1]+1),col_list17):
    x = sm.add_constant(potato_yield.index)
    result = sm.OLS(np.log(potato_yield.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','potato_yield'])
    output17 = pd.concat([output17, data], axis=0)
output17
# Out:
#         Districts  potato_yield
# 0     Chitradurga           NaN
# 0       Davangere           NaN
# 0        Bagalkot           NaN
# 0         Balgaum         0.028
# 0         Dharwad         0.135
# 0           Gadag           NaN
# 0          Haveri           NaN
# 0          Koppal           NaN
# 0   Chamrajanagar         0.042
# 0   Chikkamagalur         0.061
# 0          Hassan         0.021
# 0          Mandya         0.030
# 0     State Total         0.020
# 0  Bangalore®_new        -0.003
# 0       Kolar_new         0.008

# %%
output18 = pd.DataFrame()
for i,j in zip(np.arange(0,tomato_yield.shape[1]+1),col_list18):
    x = sm.add_constant(tomato_yield.index)
    result = sm.OLS(np.log(tomato_yield.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','tomato_yield'])
    output18 = pd.concat([output18, data], axis=0)
output18
# Out:
#         Districts  tomato_yield
# 0     Chitradurga        -0.000
# 0       Davangere         0.017
# 0        Bagalkot         0.002
# 0         Balgaum        -0.001
# 0         Dharwad         0.014
# 0           Gadag         0.035
# 0          Haveri         0.032
# 0          Koppal         0.014
# 0   Chamrajanagar         0.003
# 0   Chikkamagalur         0.017
# 0          Hassan         0.033
# 0          Mandya         0.066
# 0     State Total         0.019
# 0  Bangalore®_new         0.005
# 0       Kolar_new         0.037

# %%
output19 = pd.DataFrame()
for i,j in zip(np.arange(0,onion_yield.shape[1]+1),col_list19):
    x = sm.add_constant(onion_yield.index)
    result = sm.OLS(np.log(onion_yield.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','onion_yield'])
    output19 = pd.concat([output19, data], axis=0)
output19
# Out:
#         Districts  onion_yield
# 0     Chitradurga        0.028
# 0       Davangere        0.054
# 0        Bagalkot        0.020
# 0         Balgaum        0.077
# 0         Dharwad        0.071
# 0           Gadag       -0.004
# 0          Haveri        0.048
# 0          Koppal        0.036
# 0   Chamrajanagar       -0.003
# 0   Chikkamagalur        0.039
# 0          Hassan        0.042
# 0          Mandya        0.020
# 0     State Total        0.039
# 0  Bangalore®_new        0.033
# 0       Kolar_new        0.037

# %%
output20 = pd.DataFrame()
for i,j in zip(np.arange(0,gaurd_yield.shape[1]+1),col_list20):
    x = sm.add_constant(gaurd_yield.index)
    result = sm.OLS(np.log(gaurd_yield.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','gaurd_yield'])
    output20 = pd.concat([output20, data], axis=0)
output20
# Out:
#         Districts  gaurd_yield
# 0     Chitradurga        0.003
# 0       Davangere       -0.004
# 0        Bagalkot        0.031
# 0         Balgaum        0.000
# 0         Dharwad        0.058
# 0           Gadag        0.004
# 0          Haveri          NaN
# 0          Koppal        0.012
# 0   Chamrajanagar        0.020
# 0   Chikkamagalur        0.028
# 0          Hassan        0.052
# 0          Mandya          NaN
# 0     State Total        0.010
# 0  Bangalore®_new       -0.005
# 0       Kolar_new        0.019

# %%
output21 = pd.DataFrame()
for i,j in zip(np.arange(0,khol_yield.shape[1]+1),col_list21):
    x = sm.add_constant(khol_yield.index)
    result = sm.OLS(np.log(khol_yield.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','khol_yield'])
    output21 = pd.concat([output21, data], axis=0)
output21
# Out:
#         Districts  khol_yield
# 0     Chitradurga      -0.014
# 0       Davangere       0.017
# 0        Bagalkot       0.024
# 0         Balgaum       0.020
# 0         Dharwad       0.025
# 0           Gadag       0.011
# 0          Haveri       0.011
# 0          Koppal         NaN
# 0   Chamrajanagar      -0.020
# 0   Chikkamagalur       0.018
# 0          Hassan       0.004
# 0          Mandya       0.011
# 0     State Total       0.003
# 0  Bangalore®_new      -0.000
# 0       Kolar_new      -0.004

# %%
output22 = pd.DataFrame()
for i,j in zip(np.arange(0,leafyveg_yield.shape[1]+1),col_list22):
    x = sm.add_constant(leafyveg_yield.index)
    result = sm.OLS(np.log(leafyveg_yield.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','leafyveg_yield'])
    output22 = pd.concat([output22, data], axis=0)
output22
# Out:
#         Districts  leafyveg_yield
# 0        Bagalkot           0.015
# 0         Balgaum           0.005
# 0  Bangalore®_new          -0.001
# 0   Chamrajanagar           0.034
# 0   Chikkamagalur           0.018
# 0     Chitradurga           0.015
# 0       Davangere           0.034
# 0         Dharwad             NaN
# 0           Gadag          -0.011
# 0          Hassan           0.041
# 0          Haveri          -0.014
# 0       Kolar_new           0.015
# 0          Koppal             NaN
# 0          Mandya             NaN
# 0     State Total           0.012
# 0           years             NaN

# %%
output23 = pd.DataFrame()
for i,j in zip(np.arange(0,otherveg_yield.shape[1]+1),col_list23):
    x = sm.add_constant(otherveg_yield.index)
    result = sm.OLS(np.log(otherveg_yield.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','otherveg_yield'])
    output23 = pd.concat([output23, data], axis=0)
output23
# Out:
#         Districts  otherveg_yield
# 0     Chitradurga          -0.031
# 0       Davangere           0.005
# 0        Bagalkot          -0.012
# 0         Balgaum          -0.011
# 0         Dharwad           0.002
# 0           Gadag           0.006
# 0          Haveri          -0.004
# 0          Koppal          -0.034
# 0   Chamrajanagar          -0.054
# 0   Chikkamagalur          -0.027
# 0          Hassan          -0.004
# 0          Mandya          -0.030
# 0     State Total          -0.010
# 0  Bangalore®_new          -0.006
# 0       Kolar_new          -0.022

# %%
output24 = pd.DataFrame()
for i,j in zip(np.arange(0,total_yield.shape[1]+1),col_list24):
    x = sm.add_constant(total_yield.index)
    result = sm.OLS(np.log(total_yield.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','total_yield'])
    output24 = pd.concat([output24, data], axis=0)
output24
# Out:
#         Districts  total_yield
# 0     Chitradurga        0.023
# 0       Davangere        0.031
# 0        Bagalkot        0.018
# 0         Balgaum        0.023
# 0         Dharwad        0.054
# 0           Gadag       -0.005
# 0          Haveri        0.027
# 0          Koppal        0.016
# 0   Chamrajanagar        0.009
# 0   Chikkamagalur        0.029
# 0          Hassan        0.020
# 0          Mandya        0.034
# 0     State Total        0.022
# 0  Bangalore®_new       -0.001
# 0       Kolar_new        0.021

# %%
output = pd.DataFrame()
for i,j in zip(np.arange(0,tomato_area.shape[1]+1),col_list2):
    x = sm.add_constant(tomato_area.index)
    result = sm.OLS(np.log(tomato_area.iloc[:,i]),x).fit()
    data = [[j, result.params[1].round(3)]]
    data = pd.DataFrame(data, columns=['Districts','tomato_area'])
    output = pd.concat([output, data], axis=0)
output
# Out:
#         Districts  tomato_area
# 0     Chitradurga        0.073
# 0       Davangere        0.095
# 0        Bagalkot       -0.002
# 0         Balgaum        0.047
# 0         Dharwad        0.019
# 0           Gadag       -0.014
# 0          Haveri        0.052
# 0          Koppal        0.093
# 0   Chamrajanagar        0.147
# 0   Chikkamagalur        0.046
# 0          Hassan       -0.010
# 0          Mandya        0.043
# 0     State Total        0.034
# 0  Bangalore®_new       -0.029
# 0       Kolar_new        0.021

# %%
merge_outer=pd.merge(output1, output2,  how='outer', on='Districts')

# %%
merge_outer.head()
# Out:
#      Districts  potato_area  tomato_area
# 0  Chitradurga          NaN        0.073
# 1    Davangere          NaN        0.095
# 2     Bagalkot          NaN       -0.002
# 3      Balgaum       -0.030        0.047
# 4      Dharwad       -0.047        0.019

# %% [markdown]
# ### Growth rate for Area

# %%
growth_rate_area=[output1, output2, output3, output4, output5, output6, output7, output8]

# %%
from functools import reduce

# %%
merge_growth_rate_area= reduce(lambda left, right: pd.merge(left, right, on=['Districts'],
                                                            how='outer'),growth_rate_area)

# %%
merge_growth_rate_area.head(16)
# Out:
#          Districts  potato_area  tomato_area  onion_area  gaurd_area  \
# 0      Chitradurga          NaN        0.073       0.030    0.041000
# 1        Davangere          NaN        0.095       0.008    0.054000
# 2         Bagalkot          NaN       -0.002       0.100   -0.031000
# 3          Balgaum       -0.030        0.047       0.038    0.021000
# 4          Dharwad       -0.047        0.019      -0.030    0.107000
# 5            Gadag          NaN       -0.014       0.060    0.026000
# 6           Haveri          NaN        0.052       0.023         inf
# 7           Koppal          NaN        0.093       0.203    0.086000
# 8    Chamrajanagar        0.307        0.147       0.104    0.106000
# 9    Chikkamagalur        0.053        0.046       0.053    0.075000
# 10          Hassan       -0.039       -0.010      -0.084    0.093000
# 11          Mandya        0.055        0.043       0.021         inf
# 12     State Total       -0.025        0.034       0.036    0.028000
# ...

# %% [markdown]
#  merge_growth_rate_area.to_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\growth_rate\\growth_rate_area.xlsx")

# %%
merge_growth_rate_area.describe()
# Out:
#        potato_area  tomato_area  onion_area  gaurd_area  khol_area  \
# count     9.000000    15.000000   15.000000   15.000000  14.000000
# mean      0.026222     0.041000    0.034867         inf   0.045714
# std       0.112272     0.047339    0.067757         NaN   0.060222
# min      -0.047000    -0.029000   -0.084000   -0.031000  -0.058000
# 25%      -0.039000     0.008500    0.003500    0.023500   0.011750
# 50%      -0.025000     0.043000    0.030000    0.054000   0.044000
# 75%       0.053000     0.062500    0.056500    0.099500   0.066000
# max       0.307000     0.147000    0.203000         inf   0.162000
#
#        leafyveg_area  otherveg_area  total_area
# count      14.000000      15.000000   15.000000
# mean             NaN      -0.103000    0.030133
# std              NaN       0.058482    0.044545
# min             -inf      -0.208000   -0.038000
# 25%        -0.026000      -0.137500    0.016000
# 50%        -0.006000      -0.097000    0.028000
# ...

# %% [markdown]
# ## Growth rate for Production

# %%
growth_rate_prod=[output9, output10, output11, output12, output13, output14, output15, output16]

# %%
merge_growth_rate_prod= reduce(lambda left, right: pd.merge(left, right, on=['Districts'],
                                                            how='outer'),growth_rate_prod)

# %%
merge_growth_rate_prod.head(16)
# Out:
#          Districts  potato_prod  tomato_prod  onion_prod  gaurd_prod  \
# 0      Chitradurga          NaN        0.073       0.057    0.043000
# 1        Davangere          NaN        0.112       0.062    0.051000
# 2         Bagalkot          NaN        0.001       0.120   -0.000000
# 3          Balgaum       -0.002        0.046       0.115    0.021000
# 4          Dharwad        0.088        0.034       0.041    0.165000
# 5            Gadag          NaN        0.021       0.056    0.030000
# 6           Haveri          NaN        0.084       0.071         inf
# 7           Koppal          NaN        0.107       0.239    0.098000
# 8    Chamrajanagar        0.349        0.150       0.101    0.126000
# 9    Chikkamagalur        0.114        0.063       0.092    0.104000
# 10          Hassan       -0.018        0.023      -0.042    0.145000
# 11          Mandya        0.085        0.110       0.041         inf
# 12     State Total       -0.005        0.053       0.075    0.038000
# ...

# %%
merge_growth_rate_prod.describe()
# Out:
#        potato_prod  tomato_prod  onion_prod  gaurd_prod  khol_prod  \
# count     9.000000    15.000000   15.000000   15.000000  14.000000
# mean      0.064333     0.060733    0.070667         inf   0.053357
# std       0.119870     0.046760    0.063154         NaN   0.062017
# min      -0.044000    -0.024000   -0.042000   -0.000000  -0.072000
# 25%      -0.005000     0.028500    0.041000    0.029500   0.032250
# 50%       0.012000     0.058000    0.062000    0.051000   0.048500
# 75%       0.088000     0.095500    0.096500    0.135500   0.080250
# max       0.349000     0.150000    0.239000         inf   0.142000
#
#        leafyveg_prod  otherveg_prod  total_prod
# count      14.000000      15.000000   15.000000
# mean             NaN      -0.118333    0.051533
# std              NaN       0.054178    0.042990
# min             -inf      -0.216000   -0.032000
# 25%        -0.014000      -0.159500    0.038000
# 50%         0.010000      -0.109000    0.051000
# ...

# %%
merge_growth_rate_prod.to_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\growth_rate\\growth_rate_prod.xlsx")

# %% [markdown]
# ## Growth rate for Yield

# %%
growth_rate_yield=[output17, output18, output19, output20, output21, output22, output23, output24]

# %%
merge_growth_rate_yield= reduce(lambda left, right: pd.merge(left, right, on=['Districts'],
                                                            how='outer'),growth_rate_yield)

# %%
merge_growth_rate_yield.head(16)
# Out:
#          Districts  potato_yield  tomato_yield  onion_yield  gaurd_yield  \
# 0      Chitradurga           NaN        -0.000        0.028        0.003
# 1        Davangere           NaN         0.017        0.054       -0.004
# 2         Bagalkot           NaN         0.002        0.020        0.031
# 3          Balgaum         0.028        -0.001        0.077        0.000
# 4          Dharwad         0.135         0.014        0.071        0.058
# 5            Gadag           NaN         0.035       -0.004        0.004
# 6           Haveri           NaN         0.032        0.048          NaN
# 7           Koppal           NaN         0.014        0.036        0.012
# 8    Chamrajanagar         0.042         0.003       -0.003        0.020
# 9    Chikkamagalur         0.061         0.017        0.039        0.028
# 10          Hassan         0.021         0.033        0.042        0.052
# 11          Mandya         0.030         0.066        0.020          NaN
# ...

# %%
merge_growth_rate_yield.to_excel("E:\\Sustainable agriculture\\Veg data\\veg analysis\\growth_rate\\growth_rate_yield.xlsx")

# %%
merge_growth_rate_yield.describe()
# Out:
#        potato_yield  tomato_yield  onion_yield  gaurd_yield  khol_yield  \
# count      9.000000     15.000000    15.000000    13.000000   14.000000
# mean       0.038000      0.019533     0.035800     0.017538    0.007571
# std        0.040792      0.018341     0.022574     0.020177    0.013620
# min       -0.003000     -0.001000    -0.004000    -0.005000   -0.020000
# 25%        0.020000      0.004000     0.024000     0.003000    0.000750
# 50%        0.028000      0.017000     0.037000     0.012000    0.011000
# 75%        0.042000      0.032500     0.045000     0.028000    0.017750
# max        0.135000      0.066000     0.077000     0.058000    0.025000
#
#        leafyveg_yield  otherveg_yield  total_yield
# count       12.000000       15.000000    15.000000
# mean         0.013583       -0.015467     0.021400
# std          0.017228        0.017020     0.014151
# min         -0.014000       -0.054000    -0.005000
# 25%          0.003500       -0.028500     0.017000
# ...

# %%
concat_area_growth=pd.concat([output1, output2, output3, output4, output5, output6, output7, output8],axis=0)
# Out:
# F:\Python\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
concat_prod_growth=pd.concat([output9, output10, output11, output12, output13, output14, output15, output16],axis=1, keys=)

# %%
concat_yield_growth=pd.concat([output17, output18, output19, output20, output21, output22, output23, output24])
# Out:
# F:\Python\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
concat_prod_growth.head(15)
# Out:
#         Districts  potato_prod       Districts  tomato_prod       Districts  \
# 0     Chitradurga          NaN     Chitradurga        0.073     Chitradurga
# 0       Davangere          NaN       Davangere        0.112       Davangere
# 0        Bagalkot          NaN        Bagalkot        0.001        Bagalkot
# 0         Balgaum       -0.002         Balgaum        0.046         Balgaum
# 0         Dharwad        0.088         Dharwad        0.034         Dharwad
# 0           Gadag          NaN           Gadag        0.021           Gadag
# 0          Haveri          NaN          Haveri        0.084          Haveri
# 0          Koppal          NaN          Koppal        0.107          Koppal
# 0   Chamrajanagar        0.349   Chamrajanagar        0.150   Chamrajanagar
# 0   Chikkamagalur        0.114   Chikkamagalur        0.063   Chikkamagalur
# 0          Hassan       -0.018          Hassan        0.023          Hassan
# ...

# %%
concat_yield_growth.describe()
# Out:
#        gaurd_yield  khol_yield  leafyveg_yield  onion_yield  otherveg_yield  \
# count    13.000000   14.000000       12.000000    15.000000       15.000000
# mean      0.017538    0.007571        0.013583     0.035800       -0.015467
# std       0.020177    0.013620        0.017228     0.022574        0.017020
# min      -0.005000   -0.020000       -0.014000    -0.004000       -0.054000
# 25%       0.003000    0.000750        0.003500     0.024000       -0.028500
# 50%       0.012000    0.011000        0.015000     0.037000       -0.011000
# 75%       0.028000    0.017750        0.022000     0.045000       -0.004000
# max       0.058000    0.025000        0.041000     0.077000        0.006000
#
#        potato_yield  tomato_yield  total_yield
# count      9.000000     15.000000    15.000000
# mean       0.038000      0.019533     0.021400
# std        0.040792      0.018341     0.014151
# min       -0.003000     -0.001000    -0.005000
# ...

# %%
list(concat_yield_growth)
# Out:
# ['Districts',
#  'gaurd_yield',
#  'khol_yield',
#  'leafyveg_yield',
#  'onion_yield',
#  'otherveg_yield',
#  'potato_yield',
#  'tomato_yield',
#  'total_yield']
